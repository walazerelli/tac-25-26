# %%
import os, time, warnings, sys
from urllib.parse import urljoin
import requests
from requests.exceptions import SSLError
from bs4 import BeautifulSoup

BASE_URL = "https://max.de.wilde.web.ulb.be/camille/"
SAVE_DIR = "pdfs"
HEADERS = {"User-Agent": "Mozilla/5.0", "Referer": BASE_URL}

def safe_get(url, stream=False, timeout=30, **kwargs):
    
    try:
        import certifi
        verify_opt = certifi.where()
    except Exception:
        verify_opt = True

    try:
        resp = requests.get(url, headers=HEADERS, timeout=timeout, verify=verify_opt, stream=stream, **kwargs)
        resp.raise_for_status()
        return resp
    except SSLError:
       
        try:
            from requests.packages.urllib3.exceptions import InsecureRequestWarning
        except Exception:
            from urllib3.exceptions import InsecureRequestWarning
        warnings.simplefilter("ignore", InsecureRequestWarning)
        resp = requests.get(url, headers=HEADERS, timeout=timeout, verify=False, stream=stream, **kwargs)
        resp.raise_for_status()
        print("⚠️ Fallback SSL: verify=False activé (problème TLS local).")
        return resp

def main():
    os.makedirs(SAVE_DIR, exist_ok=True)

    # 1) page index
    r = safe_get(BASE_URL, stream=False, timeout=30)
    soup = BeautifulSoup(r.content, "html.parser")

    # 2) lister pdfs
    links = [a.get('href') for a in soup.find_all('a') if a.get('href')]
    pdfs = [h for h in links if h.lower().endswith('.pdf')]
    if not pdfs:
        print("Aucun PDF détecté.")
        return

    # 3) télécharger
    count = 0
    for href in pdfs:
        full = urljoin(BASE_URL, href)
        out = os.path.join(SAVE_DIR, os.path.basename(href))
        print("↓", out)
        r = safe_get(full, stream=True, timeout=60)
        try:
            with open(out, "wb") as f:
                for chunk in r.iter_content(8192):
                    if chunk: f.write(chunk)
            count += 1
            print("✅", out)
        finally:
            r.close()
        time.sleep(0.15)

    print(f"Terminé — {count} fichiers téléchargés.")
    if count == 51:
        print("✅ Contrôle OK: 51 PDFs récupérés.")

if __name__ == "__main__":
    main()
# Out:
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ↓ pdfs/KB_JB230_1892-08-07_01-0003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB230_1892-08-07_01-0003.pdf
# ↓ pdfs/KB_JB427_1920-01-10_01-00004.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB427_1920-01-10_01-00004.pdf
# ↓ pdfs/KB_JB555_1836-02-08_01-00002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB555_1836-02-08_01-00002.pdf
# ↓ pdfs/KB_JB638_1860-05-21_01-00002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB638_1860-05-21_01-00002.pdf
# ↓ pdfs/KB_JB773_1918-11-30_01-00002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB773_1918-11-30_01-00002.pdf
# ↓ pdfs/KB_JB838_1887-12-28_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB838_1887-12-28_01-00003.pdf
# ↓ pdfs/KB_JB230_1903-10-16_01-0002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB230_1903-10-16_01-0002.pdf
# ↓ pdfs/KB_JB427_1933-01-04_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB427_1933-01-04_01-00003.pdf
# ↓ pdfs/KB_JB555_1899-01-19_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB555_1899-01-19_01-00003.pdf
# ↓ pdfs/KB_JB638_1902-12-20_01-00002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB638_1902-12-20_01-00002.pdf
# ↓ pdfs/KB_JB773_1933-10-07_01-00007.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB773_1933-10-07_01-00007.pdf
# ↓ pdfs/KB_JB838_1911-08-03_01-00006.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB838_1911-08-03_01-00006.pdf
# ↓ pdfs/KB_JB230_1913-07-05_01-0001.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB230_1913-07-05_01-0001.pdf
# ↓ pdfs/KB_JB427_1949-07-18_01-00008.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB427_1949-07-18_01-00008.pdf
# ↓ pdfs/KB_JB555_1940-03-01_01-00004.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB555_1940-03-01_01-00004.pdf
# ↓ pdfs/KB_JB638_1946-07-18_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB638_1946-07-18_01-00003.pdf
# ↓ pdfs/KB_JB773_1950-07-22_01-00010.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB773_1950-07-22_01-00010.pdf
# ↓ pdfs/KB_JB838_1943-09-04_01-00002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB838_1943-09-04_01-00002.pdf
# ↓ pdfs/KB_JB258_1884-09-03_01-0003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB258_1884-09-03_01-0003.pdf
# ↓ pdfs/KB_JB449_1846-05-30_01-00002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB449_1846-05-30_01-00002.pdf
# ↓ pdfs/KB_JB567_1857-02-02_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB567_1857-02-02_01-00003.pdf
# ↓ pdfs/KB_JB685_1894-05-14_01-0003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB685_1894-05-14_01-0003.pdf
# ↓ pdfs/KB_JB835_1911-04-24_01-00004.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB835_1911-04-24_01-00004.pdf
# ↓ pdfs/KB_JB92_1860-02-09_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB92_1860-02-09_01-00003.pdf
# ↓ pdfs/KB_JB258_1894-12-09_01-0003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB258_1894-12-09_01-0003.pdf
# ↓ pdfs/KB_JB449_1912-01-04_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB449_1912-01-04_01-00003.pdf
# ↓ pdfs/KB_JB567_1892-01-03_01-00005.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB567_1892-01-03_01-00005.pdf
# ↓ pdfs/KB_JB685_1903-01-18_01-0002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB685_1903-01-18_01-0002.pdf
# ↓ pdfs/KB_JB835_1930-04-08_01-00006.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB835_1930-04-08_01-00006.pdf
# ↓ pdfs/KB_JB92_1873-02-06_01-00002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB92_1873-02-06_01-00002.pdf
# ↓ pdfs/KB_JB258_1906-01-09_01-0002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB258_1906-01-09_01-0002.pdf
# ↓ pdfs/KB_JB449_1947-08-29_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB449_1947-08-29_01-00003.pdf
# ↓ pdfs/KB_JB567_1924-08-30_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB567_1924-08-30_01-00003.pdf
# ↓ pdfs/KB_JB685_1913-06-07_01-0006.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB685_1913-06-07_01-0006.pdf
# ↓ pdfs/KB_JB835_1949-09-18_01-00004.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB835_1949-09-18_01-00004.pdf
# ↓ pdfs/KB_JB92_1885-09-29_01-00002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB92_1885-09-29_01-00002.pdf
# ↓ pdfs/KB_JB421_1899-05-15_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB421_1899-05-15_01-00003.pdf
# ↓ pdfs/KB_JB494_1853-10-30_01-0002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB494_1853-10-30_01-0002.pdf
# ↓ pdfs/KB_JB572_1850-03-15_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB572_1850-03-15_01-00003.pdf
# ↓ pdfs/KB_JB729_1895-10-08_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB729_1895-10-08_01-00003.pdf
# ↓ pdfs/KB_JB837_1886-12-28_01-00002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB837_1886-12-28_01-00002.pdf
# ↓ pdfs/KB_JB421_1926-10-29_01-00002.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB421_1926-10-29_01-00002.pdf
# ↓ pdfs/KB_JB494_1922-09-28_01-0005.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB494_1922-09-28_01-0005.pdf
# ↓ pdfs/KB_JB572_1927-07-20_01-00005.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB572_1927-07-20_01-00005.pdf
# ↓ pdfs/KB_JB729_1927-11-15_01-00004.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB729_1927-11-15_01-00004.pdf
# ↓ pdfs/KB_JB837_1925-01-01_01-00003.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB837_1925-01-01_01-00003.pdf
# ↓ pdfs/KB_JB421_1950-04-15_01-00004.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB421_1950-04-15_01-00004.pdf
# ↓ pdfs/KB_JB494_1939-12-08_01-0004.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB494_1939-12-08_01-0004.pdf
# ↓ pdfs/KB_JB572_1950-06-07_01-00004.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB572_1950-06-07_01-00004.pdf
# ↓ pdfs/KB_JB729_1939-10-31_01-00006.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB729_1939-10-31_01-00006.pdf
# ↓ pdfs/KB_JB837_1950-12-01_01-00007.pdf
# ⚠️ Fallback SSL: verify=False activé (problème TLS local).
# ✅ pdfs/KB_JB837_1950-12-01_01-00007.pdf
# Terminé — 51 fichiers téléchargés.
# ✅ Contrôle OK: 51 PDFs récupérés.
